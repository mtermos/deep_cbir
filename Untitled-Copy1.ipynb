# %%
from run import *

# %%
db_dict = load_db_dict()

# %%
images_list = import_images()

# %%
# images_list

# %%
model = my_model("resnet50")
# model = my_model("trained")
# model = my_model("citorch")
# model = my_model("inception")
# model = my_model("yolo")
# model = my_model("vit")
# Out:
# Using cache found in C:\Users\Mortada/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2b8f63f torch 1.8.1 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096.0MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...

# %%
img = images_list[4045]
img = Image.open(img)

plt.imshow(img)
plt.show()

img = images_list[db_dict["qidx"][1]]
img = Image.open(img)

plt.imshow(img)
plt.show()
db_dict["qidx"][1]
# Out:
# C:\Users\Mortada\.conda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   """
# C:\Users\Mortada\.conda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()
# 4045

# %%
img1 = images_list[db_dict["qidx"][1]]
results = model(img1)

# Results
results.print()
results.show()  # or .show()

results.xyxy[0]  # img1 predictions (tensor)
results.pandas().xyxy[0]
vecs1 = extract_vectors(img1)


# img2 = images_list[db_dict["qidx"][15]]
img2 = images_list[3287]
vecs2 = extract_vectors(img2)
# Out:
# image 1/1: 1024x819 (no detections)
# Speed: 18.0ms pre-process, 604.5ms inference, 1.0ms NMS per image at shape (1, 3, 640, 512)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-3b4bc65bb380> in <module>
#       8 results.xyxy[0]  # img1 predictions (tensor)
#       9 results.pandas().xyxy[0]
# ---> 10 vecs1 = extract_vectors(img1)
#      11
#      12
#
# ~\Python\Image_retrieval\deep_cbir\run.py in extract_vectors(image_path, bbxs)
#     430         input = img.cuda()
#     431
# --> 432         vecs = model(input.unsqueeze(0)).cpu().data.squeeze()
#     433
#     434     return vecs
#
# ~\.conda\envs\tf-gpu\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
# ...

# %%
torch.set_printoptions(threshold=10_000)
vecs2

# %%
vecs2.shape

# %%
dist_vec = np.linalg.norm(vecs1 - vecs2)
dist_vec

# %%
# dist_vec

# %%
db_features = extract_dataset_images_features()
db_features.shape

# %%
# save_db_features()

# %%
# db_features = load_db_features()
# db_features.shape

# %%
img_id = 1
query_image_and_show(number_of_images = 10, image_id = db_dict["qidx"][img_id], bbx= db_dict["gnd"][img_id]["bbx"])

# %%
# img2 = images_list[db_dict["qidx"][2]]
# query = extract_vectors(img2)

# dist_vec = np.linalg.norm(db_features - query, axis=1)

# %%
# image_features = torch.zeros(len(images_list), 577, 768)

# dist_vec = np.linalg.norm(image_features - query, axis= (1,2))

# %%
# query

# %%
evaluate()

# %%
# model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)

# %%
# model

# %%
# class new_model(nn.Module):
#     def __init__(self, model):
#         super().__init__()
        
#         self.image_size = model.image_size                
#         h, w = as_tuple(model.image_size)  # image sizes
#         fh, fw = as_tuple(16)  # patch sizes
#         gh, gw = h // fh, w // fw  # number of patches
#         seq_len = gh * gw
        
#         self.class_token = model.class_token
        
# #         self.pre_logits = model.pre_logits
# #         pre_logits_size = representation_size
        
#         self.patch_embedding = model.patch_embedding
#         self.positional_embedding = model.positional_embedding
#         self.transformer = model.transformer
#         self.norm = model.norm
#         self.avgpool = nn.AdaptiveAvgPool2d((1, 1))

#     def _forward_impl(self, x: Tensor) -> Tensor:
#         b, c, fh, fw = x.shape
#         x = self.patch_embedding(x)  # b,d,gh,gw
#         x = x.flatten(2).transpose(1, 2)  # b,gh*gw,d
#         if hasattr(self, 'class_token'):
#             x = torch.cat((self.class_token.expand(b, -1, -1), x), dim=1)  # b,gh*gw+1,d
#         if hasattr(self, 'positional_embedding'): 
#             x = self.positional_embedding(x)  # b,gh*gw+1,d 
#         x = self.transformer(x)  # b,gh*gw+1,d
#         if hasattr(self, 'pre_logits'):
#             x = self.pre_logits(x)
#             x = torch.tanh(x)
        
#         x = self.norm(x)
#         print(x.shape)
#         x = self.avgpool(x)
# #         x = torch.flatten(x, 1)
        
#         return x


#     def forward(self, x: Tensor) -> Tensor:
#         return self._forward_impl(x)
    
    
    
# def as_tuple(x):
#     return x if isinstance(x, tuple) else (x, x)

# %%
# features_model = new_model(model)
# features_model

# %%
# from cirtorch.datasets.datahelpers import default_loader, imresize
# from PIL import Image

# features_model.cuda()
# features_model.eval()

# image_path = images_list[1]
# with torch.no_grad():
#     transform = transforms.Compose([
#         transforms.Resize(features_model.image_size),
#         transforms.ToTensor(),
#         transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
#     ])

#     img = Image.open(image_path)
# #     imfullsize = max(img.size)

# #     img = imresize(img, model.image_size)


#     img = transform(img).unsqueeze(0)
#     input = img.cuda()

#     vecs = features_model(input).cpu().data.squeeze()

# %%
# vecs.shape

# %%
# vecs.flatten().shape

# %%
# vecs

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
model
# Out:
# Using cache found in C:\Users\Mortada/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2b8f63f torch 1.8.1 CUDA:0 (NVIDIA GeForce GTX 1050 Ti, 4096.0MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients
# Adding AutoShape...
# AutoShape(
#   (model): Model(
#     (model): Sequential(
#       (0): Focus(
#         (conv): Conv(
#           (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (act): SiLU(inplace=True)
#       )
#       (2): C3(
#         (cv1): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (cv3): Conv(
# ...

# %%
i=0
for k, v in model.named_parameters():
#     print("self.l{} = model.model.model.__getitem__({})".format(i,i))
    print("empty_model.model.__setitem__({},trained_model.model.model.__getitem__({}))".format(i,i))
    i+=1
# Out:
# empty_model.model.__setitem__(0,trained_model.model.model.__getitem__(0))
# empty_model.model.__setitem__(1,trained_model.model.model.__getitem__(1))
# empty_model.model.__setitem__(2,trained_model.model.model.__getitem__(2))
# empty_model.model.__setitem__(3,trained_model.model.model.__getitem__(3))
# empty_model.model.__setitem__(4,trained_model.model.model.__getitem__(4))
# empty_model.model.__setitem__(5,trained_model.model.model.__getitem__(5))
# empty_model.model.__setitem__(6,trained_model.model.model.__getitem__(6))
# empty_model.model.__setitem__(7,trained_model.model.model.__getitem__(7))
# empty_model.model.__setitem__(8,trained_model.model.model.__getitem__(8))
# empty_model.model.__setitem__(9,trained_model.model.model.__getitem__(9))
# empty_model.model.__setitem__(10,trained_model.model.model.__getitem__(10))
# empty_model.model.__setitem__(11,trained_model.model.model.__getitem__(11))
# empty_model.model.__setitem__(12,trained_model.model.model.__getitem__(12))
# ...

# %%
dir(model.model.model)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_backward_hooks',
#  '_get_item_by_idx',
#  '_get_name',
#  '_is_full_backward_hook',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_maybe_warn_non_full_backward_hook',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
# ...

# %%
# dir(model.model.model)
x = list(model.model.model.children())
x
# Out:
# [Sequential(
#    (0): Focus(
#      (conv): Conv(
#        (conv): Conv2d(12, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#        (act): SiLU(inplace=True)
#      )
#    )
#    (1): Conv(
#      (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#      (act): SiLU(inplace=True)
#    )
#    (2): C3(
#      (cv1): Conv(
#        (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#        (act): SiLU(inplace=True)
#      )
#      (cv2): Conv(
#        (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#        (act): SiLU(inplace=True)
#      )
#      (cv3): Conv(
#        (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#        (act): SiLU(inplace=True)
#      )
#      (m): Sequential(
#        (0): Bottleneck(
#          (cv1): Conv(
#            (conv): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#            (act): SiLU(inplace=True)
#          )
#          (cv2): Conv(
# ...

# %%
import torch


from PIL import Image
from torchvision import transforms
from torchvision import models

from run import *



db_dict = load_db_dict()
images_list = import_images()


# model = torch.hub.load('pytorch/vision:v0.10.0', 'deeplabv3_resnet101', pretrained=True)
model = models.segmentation.deeplabv3_resnet50(pretrained=1)

# model.classifier = None
# model.aux_classifier = None
# model = model.backbone
model.eval()






image_id = 2
image_path = images_list[image_id]
    
input_image = Image.open(image_path)
preprocess = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

input_tensor = preprocess(input_image)
input_batch = input_tensor.unsqueeze(0) # create a mini-batch as expected by the model

# move the input and model to GPU for speed if available
if torch.cuda.is_available():
    input_batch = input_batch.to('cuda')
    model.to('cuda')

with torch.no_grad():
    output = model(input_batch)['out'][0]
output_predictions = output.argmax(0)



# create a color pallette, selecting a color for each class
palette = torch.tensor([2 ** 25 - 1, 2 ** 15 - 1, 2 ** 21 - 1])
colors = torch.as_tensor([i for i in range(21)])[:, None] * palette
colors = (colors % 255).numpy().astype("uint8")

# plot the semantic segmentation predictions of 21 classes in each color
r = Image.fromarray(output_predictions.byte().cpu().numpy()).resize(input_image.size)
r.putpalette(colors)

import matplotlib.pyplot as plt

plt.imshow(r)
plt.show()
# plt.imshow(r)
# plt.show()
# Out:
# C:\Users\Mortada\.conda\envs\tf-gpu\lib\site-packages\ipykernel_launcher.py:64: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
